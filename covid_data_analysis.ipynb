# %% [markdown]
# <a href="https://colab.research.google.com/github/amrutha-m-sajeev/covid-data-analysis/blob/main/covid_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Read the data**

# %%
df=pd.read_csv('/content/owid-covid-data.csv')
df
#df:will show you whole data set
# Out:
#       iso_code continent                location        date  total_cases  \
# 0          AFG      Asia             Afghanistan  2020-02-24          5.0
# 1          AFG      Asia             Afghanistan  2020-02-25          5.0
# 2          AFG      Asia             Afghanistan  2020-02-26          5.0
# 3          AFG      Asia             Afghanistan  2020-02-27          5.0
# 4          AFG      Asia             Afghanistan  2020-02-28          5.0
# ...        ...       ...                     ...         ...          ...
# 29678      BIH    Europe  Bosnia and Herzegovina  2021-05-20     203018.0
# 29679      BIH    Europe  Bosnia and Herzegovina  2021-05-21     203150.0
# 29680      BIH    Europe  Bosnia and Herzegovina  2021-05-22     203150.0
# 29681      BIH    Europe  Bosnia and Herzegovina  2021-05-23     203150.0
# 29682      BIH    Europe  Bosnia and Herzegovina  2021-05-24     203391.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %% [markdown]
# ***View the Data***

# %%
#df.shape:will show you several rows and coloumns in dataset
df.shape
# Out:
# (29683, 67)

# %%
#df.head():it will show the frist 5 rows as default.if you want to return the frist 10 rows then insert a value in parenthesis
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
#df.describe():it will show the basic summary of data such as count,min,max,unique values
df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  2.957900e+04  2.955100e+04        29411.000000  2.809000e+04
# mean   3.826706e+06  8.832086e+03         8864.154157  4.596775e+04
# std    2.042454e+07  4.981194e+04        49318.209612  2.005407e+05
# min    1.000000e+00  0.000000e+00            0.000000  1.000000e+00
# 25%    7.413000e+03  0.000000e+00            7.857000  1.260000e+02
# 50%    5.853200e+04  5.200000e+01           80.143000  1.053000e+03
# 75%    5.130030e+05  7.230000e+02          935.143000  8.683000e+03
# max    2.100816e+08  1.100819e+06       884662.857000  1.620395e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  28084.000000         27939.000000             29579.000000
# mean      77.872810            78.233539             83558.383285
# std      530.748461           404.681216            129652.084990
# min        0.000000             0.000000                 0.001000
# ...

# %% [markdown]
# **Dropping the column:**

# %%
#df.drop():It drop the specific column or row of a dataset.We will look at how to drop a column
df.drop(['new_cases_smoothed'],axis=1)
# Out:
#       iso_code continent                location        date  total_cases  \
# 0          AFG      Asia             Afghanistan  2020-02-24          5.0
# 1          AFG      Asia             Afghanistan  2020-02-25          5.0
# 2          AFG      Asia             Afghanistan  2020-02-26          5.0
# 3          AFG      Asia             Afghanistan  2020-02-27          5.0
# 4          AFG      Asia             Afghanistan  2020-02-28          5.0
# ...        ...       ...                     ...         ...          ...
# 29678      BIH    Europe  Bosnia and Herzegovina  2021-05-20     203018.0
# 29679      BIH    Europe  Bosnia and Herzegovina  2021-05-21     203150.0
# 29680      BIH    Europe  Bosnia and Herzegovina  2021-05-22     203150.0
# 29681      BIH    Europe  Bosnia and Herzegovina  2021-05-23     203150.0
# 29682      BIH    Europe  Bosnia and Herzegovina  2021-05-24     203391.0
#
#        new_cases  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %% [markdown]
# For multiple deletion of column

# %%
df.drop(['new_deaths_smoothed','new_cases_per_million','total_cases_per_million'],axis=1)
df
# Out:
#       iso_code continent                location        date  total_cases  \
# 0          AFG      Asia             Afghanistan  2020-02-24          5.0
# 1          AFG      Asia             Afghanistan  2020-02-25          5.0
# 2          AFG      Asia             Afghanistan  2020-02-26          5.0
# 3          AFG      Asia             Afghanistan  2020-02-27          5.0
# 4          AFG      Asia             Afghanistan  2020-02-28          5.0
# ...        ...       ...                     ...         ...          ...
# 29678      BIH    Europe  Bosnia and Herzegovina  2021-05-20     203018.0
# 29679      BIH    Europe  Bosnia and Herzegovina  2021-05-21     203150.0
# 29680      BIH    Europe  Bosnia and Herzegovina  2021-05-22     203150.0
# 29681      BIH    Europe  Bosnia and Herzegovina  2021-05-23     203150.0
# 29682      BIH    Europe  Bosnia and Herzegovina  2021-05-24     203391.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %% [markdown]
# **Renaming the column name:**

# %%
#df.rename():We can rename column name,row name,or index.In our data set we will rename the coloumn
df.rename(columns={'date': 'Date','location':'Country','continent': 'Continent','iso_code':'ISO_code'},inplace=True)
df
# Out:
#       ISO_code Continent                 Country        Date  total_cases  \
# 0          AFG      Asia             Afghanistan  2020-02-24          5.0
# 1          AFG      Asia             Afghanistan  2020-02-25          5.0
# 2          AFG      Asia             Afghanistan  2020-02-26          5.0
# 3          AFG      Asia             Afghanistan  2020-02-27          5.0
# 4          AFG      Asia             Afghanistan  2020-02-28          5.0
# ...        ...       ...                     ...         ...          ...
# 29678      BIH    Europe  Bosnia and Herzegovina  2021-05-20     203018.0
# 29679      BIH    Europe  Bosnia and Herzegovina  2021-05-21     203150.0
# 29680      BIH    Europe  Bosnia and Herzegovina  2021-05-22     203150.0
# 29681      BIH    Europe  Bosnia and Herzegovina  2021-05-23     203150.0
# 29682      BIH    Europe  Bosnia and Herzegovina  2021-05-24     203391.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %% [markdown]
# **List the continent name:**

# %%
Continent=list(df.Continent.unique())
Continent
# Out:
# ['Asia', nan, 'Europe', 'Africa', 'North America', 'South America', 'Oceania']

# %% [markdown]
# **Finding mising values**

# %%
df.isna().sum()
# Out:
# ISO_code                                       0
# Continent                                   2220
# Country                                        0
# Date                                           0
# total_cases                                  104
#                                            ...
# population                                     1
# excess_mortality_cumulative_absolute       28914
# excess_mortality_cumulative                28914
# excess_mortality                           28914
# excess_mortality_cumulative_per_million    28914
# Length: 67, dtype: int64

# %% [markdown]
# filling the missing value

# %%
df1=df.fillna('missing')
df1
# Out:
#       ISO_code Continent                 Country        Date total_cases  \
# 0          AFG      Asia             Afghanistan  2020-02-24         5.0
# 1          AFG      Asia             Afghanistan  2020-02-25         5.0
# 2          AFG      Asia             Afghanistan  2020-02-26         5.0
# 3          AFG      Asia             Afghanistan  2020-02-27         5.0
# 4          AFG      Asia             Afghanistan  2020-02-28         5.0
# ...        ...       ...                     ...         ...         ...
# 29678      BIH    Europe  Bosnia and Herzegovina  2021-05-20    203018.0
# 29679      BIH    Europe  Bosnia and Herzegovina  2021-05-21    203150.0
# 29680      BIH    Europe  Bosnia and Herzegovina  2021-05-22    203150.0
# 29681      BIH    Europe  Bosnia and Herzegovina  2021-05-23    203150.0
# 29682      BIH    Europe  Bosnia and Herzegovina  2021-05-24    203391.0
#
#       new_cases new_cases_smoothed total_deaths new_deaths  \
# ...

# %%
df1.isna().sum()
# Out:
# ISO_code                                   0
# Continent                                  0
# Country                                    0
# Date                                       0
# total_cases                                0
#                                           ..
# population                                 0
# excess_mortality_cumulative_absolute       0
# excess_mortality_cumulative                0
# excess_mortality                           0
# excess_mortality_cumulative_per_million    0
# Length: 67, dtype: int64

# %% [markdown]
# **Using Groupby**

# %%
#df.groupby():The groupby command allows us to divide our data into different groups and perform our data analysis
df2 = df.groupby(['Date','Country',])[['Date','Country','total_cases','total_deaths','total_vaccinations']].sum().reset_index()
df2
# Out:
#              Date                          Country  total_cases  total_deaths  \
# 0      2020-01-01                        Argentina          0.0           0.0
# 1      2020-01-02                        Argentina          0.0           0.0
# 2      2020-01-03                        Argentina          0.0           0.0
# 3      2020-01-04                        Argentina          0.0           0.0
# 4      2020-01-05                        Argentina          0.0           0.0
# ...           ...                              ...          ...           ...
# 29678  2023-02-15                          Bermuda      18791.0         159.0
# 29679  2023-02-15                           Bhutan      62611.0          21.0
# 29680  2023-02-15                          Bolivia    1191492.0       22356.0
# 29681  2023-02-15  Bonaire Sint Eustatius and Saba      11797.0          41.0
# 29682  2023-02-16                          Austria          0.0           0.0
#
#        total_vaccinations
# ...

# %%
#replacing missing value
df1['total_deaths'].replace({'missing':0},inplace=True)
df1
# Out:
#       ISO_code Continent                 Country        Date total_cases  \
# 0          AFG      Asia             Afghanistan  2020-02-24         5.0
# 1          AFG      Asia             Afghanistan  2020-02-25         5.0
# 2          AFG      Asia             Afghanistan  2020-02-26         5.0
# 3          AFG      Asia             Afghanistan  2020-02-27         5.0
# 4          AFG      Asia             Afghanistan  2020-02-28         5.0
# ...        ...       ...                     ...         ...         ...
# 29678      BIH    Europe  Bosnia and Herzegovina  2021-05-20    203018.0
# 29679      BIH    Europe  Bosnia and Herzegovina  2021-05-21    203150.0
# 29680      BIH    Europe  Bosnia and Herzegovina  2021-05-22    203150.0
# 29681      BIH    Europe  Bosnia and Herzegovina  2021-05-23    203150.0
# 29682      BIH    Europe  Bosnia and Herzegovina  2021-05-24    203391.0
#
#       new_cases new_cases_smoothed  total_deaths new_deaths  \
# ...

# %% [markdown]
# Finding total countires where total_deaths is greater than 1000000

# %%
df3=df1[df1['total_deaths']>1000000]
countries=df3['Country'].unique()
len(countries)
# Out:
# 1

# %%
country_deaths_greaterthan_1000000=list(df3.Country.unique())
country_deaths_greaterthan_1000000
# Out:
# ['Asia']
